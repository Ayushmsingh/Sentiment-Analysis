# %% [markdown]
# # Depression Detection in Tweets

# %% [raw]
# IMPORTING TWEETS

# %%
import nltk  # for text manipulation 
import string # for text manipulation 
import warnings 
import numpy as np 
import pandas as pd # for data manipulation 
import matplotlib.pyplot as plt
import re
from textblob import TextBlob

pd.set_option("display.max_colwidth", 200) 
warnings.filterwarnings("ignore") #ignore warnings

# %% [markdown]
# # Data Preparation

# %% [raw]
# TAKING DATA OF PARTICULAR HASHTAGS AND CONCATENATE THEM

# %%
df1=pd.read_csv("./data/worthless.csv")
df1.columns=["time","tweet","user","location"]

df2=pd.read_csv("./data/tears.csv")
df2.columns=["time","tweet","user","location"]

df3=pd.read_csv("./data/stuck.csv")
df3.columns=["time","tweet","user","location"]

df4=pd.read_csv("./data/sad.csv")
df4.columns=["time","tweet","user","location"]

df5=pd.read_csv("./data/panic.csv")
df5.columns=["time","tweet","user","location"]

df6=pd.read_csv("./data/misery.csv")
df6.columns=["time","tweet","user","location"]

df7=pd.read_csv("./data/lost.csv")
df7.columns=["time","tweet","user","location"]

df8=pd.read_csv("./data/insecure.csv")
df8.columns=["time","tweet","user","location"]

# df9=pd.read_csv("data/hurt.csv")
# df9.columns=["time","tweet","user","location"]

df10=pd.read_csv("./data/hopeless.csv")
df10.columns=["time","tweet","user","location"]

df11=pd.read_csv("./data/helpless.csv")
df11.columns=["time","tweet","user","location"]

df12=pd.read_csv("./data/despair.csv")
df12.columns=["time","tweet","user","location"]

df13=pd.read_csv("./data/depressing.csv")
df13.columns=["time","tweet","user","location"]

df14=pd.read_csv("./data/depressed.csv")
df14.columns=["time","tweet","user","location"]

df15=pd.read_csv("./data/alone.csv")
df15.columns=["time","tweet","user","location"]

# %% [raw]
# CONCATENATE ALL TWEETS IN ONE DATAFRAME

# %%
df = pd.concat([df1, df2,df3,df4,df5,df7,df8,df10,df11,df12,df13,df14,df15], axis=0)
df.sample(25)
# Out:
#                           time
# 26         2022-10-10 15:53:15  \
# 41         2022-10-10 21:11:37
# 301  2022-10-07 22:54:30+00:00
# 818  2022-09-19 12:13:26+00:00
# 181        2022-10-10 08:52:22
# 27   2022-09-20 23:00:29+00:00
# 423        2022-10-07 17:15:57
# 54   2022-10-10 02:00:19+00:00
# 375  2022-09-15 21:34:06+00:00
# 451  2022-09-15 09:30:37+00:00
# 513  2022-09-14 13:25:26+00:00
# 611        2022-10-05 17:24:33
# 555  2022-09-13 08:08:18+00:00
# 211  2022-09-18 13:37:40+00:00
# 713  2022-09-12 21:45:51+00:00
# 432  2022-10-08 04:00:40+00:00
# 125        2022-10-03 19:13:05
# 258  2022-10-11 18:37:02+00:00
# 546  2022-09-14 01:11:30+00:00
# 448                        NaN
# 614        2022-10-05 17:05:12
# 13   2022-10-11 17:09:11+00:00
# 171  2022-10-10 18:22:06+00:00
# 280  2022-10-07 21:44:56+00:00
# 168                        NaN
#
#                                                                                                                                                                                                        tweet
# 26                                                b'@ro536813 @ICICIBank_Care @RBI @DasShaktikanta @RubikaLiyaquat @anjanaomkashyap @ravishndtv @AnjaliJajodia Its been\xe2\x80\xa6 https://t.co/zQVRU7DUWn'  \
# 41                                                          b'@theipaper @kiaelise1 Who gives a shit in the big picture of world news. Cannot believe this is trending.\xe2\x80\xa6 https://t.co/BQnsAOYzl5'
# 301                                                                                            b'Who working for the F.E.D.\xe2\x80\x99s @kanyewest. #Tears\xf0\x9f\x98\x82\xf0\x9f\xa4\xa3\xf0\x9f\x98\xad'
# 818                                                                                                                                               b'This is one #sad human being !! https://t.co/2flrVg34rr'
# 181                           b'There\xe2\x80\x99s just something about the host of #TheMole \n\nWhy does she remind me of Evangeline Lilly from #Lost \xf0\x9f\xa4\x94\xe2\x80\xa6 https://t.co/kuKQZNztki'
# 27                                                                                                                               b'Good morning, Twitter! Have a Great day to all ! ! ! ! ! ! #bored #alone'
# 423                            b'Pre-Order NOW\xe2\x80\xa6\nhttps://t.co/6HckwudbNj\n\nOcean\xe2\x80\x99s Eleven meetings The Walking Dead and The Avengers.\n\n#Zombie\xe2\x80\xa6 https://t.co/KFWo6xyhYA'
# 54                                                            b'China Warns About US Chip Restrictions That Will Soon Hurt the Global Supply Chains #roboticsainews #ai\xe2\x80\xa6 https://t.co/Jr7TjWnlFS'
# 375  b'@chaoticsalami YESSIR \xf0\x9f\x98\x94\xf0\x9f\x98\x94\xf0\x9f\x98\x94\xf0\x9f\x98\x94\xf0\x9f\x98\xad\xf0\x9f\x98\xad\xf0\x9f\x98\xad\xf0\x9f\x98\xad\xf0\x9f\x98\xad\xf0\x9f\x98\xad #depressed ...
# 451  b'\xe2\x96\xb6 #NowPlaying \xf0\x9f\x93\xbb Alone by Rod Wave @rodwave on Hot 21 Radio \n \n \xf0\x9f\x8e\xa7 LISTEN =&gt; https://t.co/5Woa6bELDB\n\n \xf0\x9f\x91\x8d LIKE =&gt;\xe2\x80\xa6 https...
# 513                                               b'@ARC_Storyteller Yes.. and i had to stand up for my self. Its a long story but I took matter into my own hands, she\xe2\x80\xa6 https://t.co/fECirFZE48'
# 611                                                                                                 b'Officially the coolest things I own \xf0\x9f\x9b\xa9\xf0\x9f\x8f\x9d\n\n#LOST https://t.co/CCeft1kkW5'
# 555                                              b'A Streamer Reacts to The Queens Death.\n#QueenElizabeth #queendead #sadday #grief #uk #NotMyKing #news #breakingnews\xe2\x80\xa6 https://t.co/vAobqbsl15'
# 211          b'God is with me. #phillipians413 #grateful #never #alone \xf0\x9f\x91\x91\xe2\x9d\xa4\xf0\x9f\xa6\x8b\xf0\x9f\x99\x8f\xf0\x9f\x8f\xbe\xf0\x9f\x99\x8c\xf0\x9f\x8f\xbe https://t.co/DiQVVBoasQ'
# 713                                                                          b'Repping my @HauntedNights_ merch for episode 2 of Mid Orange \xf0\x9f\x91\xbb\xf0\x9f\x98\x88 #Alone https://t.co/so802yqsNQ'
# 432                                                                                                                      b"12 AM EST Reminder: You are ok. You are safe. Don't panic. #anxiety #calm #panic"
# 125                                               b'@actornfotog @MumbaiPolice @CPMumbaiPolice @DGPMaharashtra @ThaneCityPolice @Thane_R_Police They always hiding behi\xe2\x80\xa6 https://t.co/5i7Yayn9Fq'
# 258                                                     b"And sadly their growth, is growth in #Poverty #Misery and #Despair for #Workers.\nLet's remember we are many.\xe2\x80\xa6 https://t.co/38Lbuzvttx"
# 546                                                                   b'Getting the   #Snow #Weather #Street #Bicyle #Winter #Alone #Transportation #Man #People #Wheel\xe2\x80\xa6 https://t.co/jEEdzHtgAs'
# 448                                                                                                                                                                                                      NaN
# 614                                               b'Want to #automate your #sales but are #lost on where to start?  #Breakthrough3x can #guide you, without the pain! A\xe2\x80\xa6 https://t.co/JCgYFkyKP9'
# 13                                                                  b'@azeyIia pls stop being homophobic #hurt #pain #ouch \xf0\x9f\x98\x94\xf0\x9f\x98\x94\xf0\x9f\x98\x94\xf0\x9f\x98\x94\xf0\x9f\x98\x94'
# 171                                               b'@AyubYoussef #Tears of #Sand, #MasksOff #Extremes &amp; #Balance #Stonewalling r #poems of #part #two of my #poetry\xe2\x80\xa6 https://t.co/FFhm5r9dbd'
# 280                                                      b'@nadhimzahawi @trussliz Growth? \n\nOf #poverty and of #pestilence? \nOf #division and of #intolerance? \nOf\xe2\x80\xa6 https://t.co/AVBHJvzw6e'
# 168                                                                                                                                                                                                      NaN
#
#                    user                       location
# 26   b'RahulKu22205585'                            b''
# 41         b'kathrynmk'   b'Here, there & everywhere.'
# 301    b'3Jaymoneybags'                  b'Top Secret'
# 818          b'UGA1970'        b'East Central Georgia'
# 181     b'lyndashinobi'     b'England, United Kingdom'
# 27   b'Marian_Stuart19'      b'United States, Newyork'
# 423      b'VaughnAshby'            b'Aurora Wasteland'
# 54    b'RoboticsAINews'                   b'Australia'
# 375       b'ShadoArt__'                   b'They/them'
# 451       b'hot21radio'                   b'Worldwide'
# 513   b'harleyriding99'                      b'Canada'
# 611     b'saffandahalf'     b'still at the restaurant'
# 555   b'The_Aquarius_X'                            b''
# 211        b'arnita_ds'  b'Philadelphia Pennsylvania '
# 713   b'KaitlynRankin2'                            b''
# 432     b'CalmReminder'               b'United States'
# 125         b'_ketan31'                b'Thane, India'
# 258        b'LindenLyn'                       b'Devon'
# 546    b'AlexAlicea331'           b'New York, NY, USA'
# 448                 NaN                            NaN
# 614     b'dan_kuschell'              b'Scottsdale, AZ'
# 13        b'ceetoplasm'                       b'nami '
# 171     b'PasitheaChan'                            b''
# 280    b'RaffyFlynnArt'             b'South Wales, UK'
# 168                 NaN                            NaN

# %%
df.shape
# Out:
# (5404, 4)

# %%
df.drop(['user','time','location'],axis = 1,inplace = True)
df.head()
# Out:
#                                                                                                                                                                tweet
# 0         b'@laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'
# 1                                                                                              b'@laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'

# %% [markdown]
# # Data Cleaning

# %% [raw]
# REMOVING @ , USERS

# %%
df['Clean_TweetText'] = df['tweet'].str.replace("@", "") 
df.head()
# Out:
#                                                                                                                                                                tweet
# 0         b'@laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'  \
# 1                                                                                              b'@laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'
#
#                                                                                                                                                      Clean_TweetText
# 0          b'laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'
# 1                                                                                               b'laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'

# %% [raw]
# REMOVING LINKS, HTTP://

# %%
df['Clean_TweetText'] = df['Clean_TweetText'].str.replace(r"http\S+", "") 
df.head()
# Out:
#                                                                                                                                                                tweet
# 0         b'@laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'  \
# 1                                                                                              b'@laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'
#
#                                                                                                                                                      Clean_TweetText
# 0          b'laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'
# 1                                                                                               b'laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'

# %%
df['Clean_TweetText'] = df['Clean_TweetText'].str.replace(r"https\S+", "") 
df.head()
# Out:
#                                                                                                                                                                tweet
# 0         b'@laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'  \
# 1                                                                                              b'@laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'
#
#                                                                                                                                                      Clean_TweetText
# 0          b'laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'
# 1                                                                                               b'laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'

# %% [raw]
# REMOVING PUNCTUATIONS, NUMBERS AND SPECIAL CHARACTERS

# %%
df['Clean_TweetText'] = df['Clean_TweetText'].str.replace("[^a-zA-Z]", " ") 
df.head()
# Out:
#                                                                                                                                                                tweet
# 0         b'@laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'  \
# 1                                                                                              b'@laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'
#
#                                                                                                                                                      Clean_TweetText
# 0          b'laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'
# 1                                                                                               b'laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'

# %% [raw]
# REMOVE NAN VALUES

# %%
df1=df.dropna()
df1.drop(['tweet'],axis = 1,inplace = True)
df1.head()
# Out:
#                                                                                                                                                      Clean_TweetText
# 0          b'laurenboebert How bout getting  a fucking  pro gun/ anti security state bill through Congress for once? Enough wit\xe2\x80\xa6 https://t.co/OgikovyYuj'
# 1                                                                                               b'laurenboebert And this has what to do with Colorado??  #worthless'
# 2                              b'Russia\xe2\x80\x99s activities in Ukraine show the uselessness of the United Nations. #UkraineRussianWar #UnitedNations #worthless'
# 3         b'I am so hurt and any support is desperately needed and would mean everything. #Victims beat ourselves up worse than\xe2\x80\xa6 https://t.co/nJJPM6lndm'
# 4  b'Favorite #Bible Verses\xe2\x80\x94a Comparison of Philippians 3:7-9 in four translations https://t.co/qhPxQ1fBbb #Valuable\xe2\x80\xa6 https://t.co/QcK8RtOB7W'

# %%
df1.shape
# Out:
# (5080, 1)

# %% [raw]
# REMOVING STOPWORDS

# %%
import nltk
nltk.download('stopwords')
stopwords=nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    clean_text=' '.join([word for word in text.split() if word not in stopwords])
    return clean_text

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda text : remove_stopwords(text.lower()))
df1.head()
# Out:
#                                                                                                                                                Clean_TweetText
# 0                        b'laurenboebert bout getting fucking pro gun/ anti security state bill congress once? enough wit\xe2\x80\xa6 https://t.co/ogikovyyuj'
# 1                                                                                                                       b'laurenboebert colorado?? #worthless'
# 2                                      b'russia\xe2\x80\x99s activities ukraine show uselessness united nations. #ukrainerussianwar #unitednations #worthless'
# 3                                     b'i hurt support desperately needed would mean everything. #victims beat worse than\xe2\x80\xa6 https://t.co/njjpm6lndm'
# 4  b'favorite #bible verses\xe2\x80\x94a comparison philippians 3:7-9 four translations https://t.co/qhpxq1fbbb #valuable\xe2\x80\xa6 https://t.co/qck8rtob7w'

# %% [raw]
# TEXT TOKENIZATION AND NORMALIZATION

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: x.split())
df1.head()
# Out:
#                                                                                                                                                            Clean_TweetText
# 0                    [b'laurenboebert, bout, getting, fucking, pro, gun/, anti, security, state, bill, congress, once?, enough, wit\xe2\x80\xa6, https://t.co/ogikovyyuj']
# 1                                                                                                                               [b'laurenboebert, colorado??, #worthless']
# 2                                       [b'russia\xe2\x80\x99s, activities, ukraine, show, uselessness, united, nations., #ukrainerussianwar, #unitednations, #worthless']
# 3                                   [b'i, hurt, support, desperately, needed, would, mean, everything., #victims, beat, worse, than\xe2\x80\xa6, https://t.co/njjpm6lndm']
# 4  [b'favorite, #bible, verses\xe2\x80\x94a, comparison, philippians, 3:7-9, four, translations, https://t.co/qhpxq1fbbb, #valuable\xe2\x80\xa6, https://t.co/qck8rtob7w']

# %%
from nltk.stem.porter import * 
stemmer = PorterStemmer() 
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: [stemmer.stem(i) for i in x])
df1.head()
# Out:
#                                                                                                                                                     Clean_TweetText
# 0                       [b'laurenboebert, bout, get, fuck, pro, gun/, anti, secur, state, bill, congress, once?, enough, wit\xe2\x80\xa6, https://t.co/ogikovyyuj']
# 1                                                                                                                        [b'laurenboebert, colorado??, #worthless']
# 2                                                   [b'russia\xe2\x80\x99, activ, ukrain, show, useless, unit, nations., #ukrainerussianwar, #unitedn, #worthless']
# 3                                     [b'i, hurt, support, desper, need, would, mean, everything., #victim, beat, wors, than\xe2\x80\xa6, https://t.co/njjpm6lndm']
# 4  [b'favorit, #bibl, verses\xe2\x80\x94a, comparison, philippian, 3:7-9, four, translat, https://t.co/qhpxq1fbbb, #valuable\xe2\x80\xa6, https://t.co/qck8rtob7w']

# %% [raw]
# STITCHING THESE TOKENS TOGETHER

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: ' '.join([w for w in x]))
df1.head()
# Out:
#                                                                                                                                         Clean_TweetText
# 0                           b'laurenboebert bout get fuck pro gun/ anti secur state bill congress once? enough wit\xe2\x80\xa6 https://t.co/ogikovyyuj'
# 1                                                                                                                b'laurenboebert colorado?? #worthless'
# 2                                                  b'russia\xe2\x80\x99 activ ukrain show useless unit nations. #ukrainerussianwar #unitedn #worthless'
# 3                                       b'i hurt support desper need would mean everything. #victim beat wors than\xe2\x80\xa6 https://t.co/njjpm6lndm'
# 4  b'favorit #bibl verses\xe2\x80\x94a comparison philippian 3:7-9 four translat https://t.co/qhpxq1fbbb #valuable\xe2\x80\xa6 https://t.co/qck8rtob7w'

# %% [raw]
# REMOVING SMALL WORDS

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
df1.head()
# Out:
#                                                                                                                                         Clean_TweetText
# 0                                   b'laurenboebert bout fuck gun/ anti secur state bill congress once? enough wit\xe2\x80\xa6 https://t.co/ogikovyyuj'
# 1                                                                                                                b'laurenboebert colorado?? #worthless'
# 2                                                  b'russia\xe2\x80\x99 activ ukrain show useless unit nations. #ukrainerussianwar #unitedn #worthless'
# 3                                           hurt support desper need would mean everything. #victim beat wors than\xe2\x80\xa6 https://t.co/njjpm6lndm'
# 4  b'favorit #bibl verses\xe2\x80\x94a comparison philippian 3:7-9 four translat https://t.co/qhpxq1fbbb #valuable\xe2\x80\xa6 https://t.co/qck8rtob7w'

# %% [markdown]
# # Data Visualization

# %%
all_words = ' '.join([text for text in df1['Clean_TweetText']])

from wordcloud import WordCloud 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words) 

plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off') 
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity
df1['polarity'] = df1['Clean_TweetText'].apply(polarity)
df1['subjectivity'] = df1['Clean_TweetText'].apply(subjectivity)

# %%
df1.head()
# Out:
#                                                                                                                                         Clean_TweetText
# 0                                   b'laurenboebert bout fuck gun/ anti secur state bill congress once? enough wit\xe2\x80\xa6 https://t.co/ogikovyyuj'  \
# 1                                                                                                                b'laurenboebert colorado?? #worthless'
# 2                                                  b'russia\xe2\x80\x99 activ ukrain show useless unit nations. #ukrainerussianwar #unitedn #worthless'
# 3                                           hurt support desper need would mean everything. #victim beat wors than\xe2\x80\xa6 https://t.co/njjpm6lndm'
# 4  b'favorit #bibl verses\xe2\x80\x94a comparison philippian 3:7-9 four translat https://t.co/qhpxq1fbbb #valuable\xe2\x80\xa6 https://t.co/qck8rtob7w'
#
#    polarity  subjectivity
# 0  -0.20000       0.55000
# 1  -0.80000       0.90000
# 2  -0.65000       0.55000
# 3  -0.19375       0.36875
# 4   0.00000       0.00000

# %%
#visualizations

# Let’s plot the results
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]
for index, Tweets in enumerate(df1.index):
    x = df1.polarity.loc[Tweets]
    y = df1.subjectivity.loc[Tweets]
    plt.scatter(x, y, color='Red')
 
 
plt.title('Sentiment Analysis', fontsize = 20)
plt.xlabel('← Negative — — — — — — Positive →', fontsize=15)
plt.ylabel('← Facts — — — — — — — Opinions →', fontsize=15)
# Out:
# Text(0, 0.5, '← Facts — — — — — — — Opinions →')
# Error in callback <function _draw_all_if_interactive at 0x000002B420363EC0> (for post_execute):

# %%
# Creating function for calculating positive, negative and neutral
# More than 1 --> Positive, equal to 0 --> neutral and less than 0 --> Negative
def ratio(x):
    if x > 0:
        return 1
    elif x == 0:
        return 0
    else:
        return -1
df1['analysis'] = df1['polarity'].apply(ratio)

# %%
df1.head()

# %%
df1['analysis'].value_counts()

# %%
df1['analysis'] = df1['analysis'].replace([-1,0,1],[0,1,2])

# %%
df1['analysis'].value_counts()

# %% [markdown]
# *here 0 means depressive tweets, 1 means neutral tweets and 2 means positive tweets*

# %%
# Plotting
df1['analysis'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Word Clouds

# %% [markdown]
# word cloud for positive words

# %%
positive_words =' '.join([text for text in df1['Clean_TweetText'][df1['analysis'] == 2]]) 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(positive_words)

plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off') 
plt.show()

# %% [markdown]
# word cloud for depressive words

# %%
depressive_words =' '.join([text for text in df1['Clean_TweetText'][df1['analysis'] == 0]]) 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(depressive_words)

plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off') 
plt.show()

# %% [markdown]
# # Model Building

# %%
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression 
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vectorizer = CountVectorizer(stop_words='english') 
cv = count_vectorizer.fit_transform(df1['Clean_TweetText'])
cv.shape

# %%
X_train,X_test,y_train,y_test = train_test_split(cv,df1['analysis'] , test_size=.2,stratify=df1['analysis'], random_state=42)

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# # XGBoost Classifier

# %%
xgbc = XGBClassifier(max_depth=6, n_estimators=1000, nthread= 3)
xgbc.fit(X_train,y_train)
prediction_xgb = xgbc.predict(X_test)
print(accuracy_score(prediction_xgb,y_test))

# %%
from sklearn import metrics
print(metrics.classification_report(y_test,prediction_xgb))

# %%
confusion_matrix=metrics.confusion_matrix(y_test,prediction_xgb)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=['Neutral','Positive','Depressed'])
cm_display.plot()
plt.show()

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier(n_estimators=1000, random_state=42)
rf.fit(X_train,y_train)
prediction_rf = rf.predict(X_test)
print(accuracy_score(prediction_rf,y_test))

# %%
from sklearn import metrics
print(metrics.classification_report(y_test,prediction_rf))

# %%
confusion_matrix=metrics.confusion_matrix(y_test,prediction_rf)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=['Neutral','Positive','Depressed'])
cm_display.plot()
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
prediction_lr = lr.predict(X_test)
print(accuracy_score(prediction_lr,y_test))

# %%
from sklearn import metrics
print(metrics.classification_report(y_test,prediction_lr))

# %%
confusion_matrix=metrics.confusion_matrix(y_test,prediction_lr)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=['Neutral','Positive','Depressed'])
cm_display.plot()
plt.show()

# %% [markdown]
# # Support Vector Machines (SVM)

# %%
svc = svm.SVC()
svc.fit(X_train,y_train)
prediction_svc = svc.predict(X_test)
print(accuracy_score(prediction_svc,y_test))

# %%
from sklearn import metrics
print(metrics.classification_report(y_test,prediction_svc))

# %%
confusion_matrix=metrics.confusion_matrix(y_test,prediction_svc)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=['Neutral','Positive','Depressed'])
cm_display.plot()
plt.show()
