# %%
# Import Libraries
from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# %%
consumerKey = "ht5wFjij2uE2PAYCJGXvz7GZj"
consumerSecret = "shqczmN4y0qvxa7FPrIZbndEuz8y2deBieWZ6KPl3IRaU7wMcq"
accessToken = "1569935221012987904-jfTrFH3RDUDBsQqyr5vO1IDvryryjB"
accessTokenSecret = "1U1Yg5MTYsiRNR8dcCkhDyROWwLmGP0NSQkcyVYFz6gZC"

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
tweets = api.search("ukraine", tweet_mode="extended")

for tweet in tweets:
    try:
        print(tweet.retweeted_status.full_text)
        print("=====")
    except AttributeError:
        print(tweet.full_text)
        print("=====")
# Out:
# Elon Musk blocks Ukraine from using Starlink in Crimea over concern that Putin could use nuclear weapons: report https://t.co/80R7vCSEwt
# =====
# Support Ukraine by helping purchase vital communication equipment for defenders of Ukraine; it is more crucial than ever:
# https://t.co/jiwAXOQJlq
#
# ✅Tax-deductible.
# ✅We got 20%
#
# Watch the video; these guys were born and raised in Donbas. They speak russian, and they are Ukraine https://t.co/XnYopgmThP
# =====
# Stoltenberg OTAN « Si Poutine gagne, ce sera une défaite non seulement pour l’Ukraine mais aussi une défaite et un danger pour nous tous… ce qui nous rendrait vulnérables à des agressions futures»
# L’OTAN admet implicitement être en guerre contre la Russie ? https://t.co/ZIHEy8gr9Q
# =====
# More of their work, hitting Russian truck with a German-supplied DM22 PARM 2 off-route mine.
#
# #Russia #Ukraine https://t.co/dxTve8arR1 https://t.co/LB9dRafWIX
# =====
# ...

# %%
extracted_tweets = []

for status in tweepy.Cursor(api.search, 
                            "Ukraine", 
                            lang="en",
                            count=100).items(250):
    extracted_tweets.append(status)

# %%
x = pd.DataFrame(extracted_tweets)
x.to_csv("tweepy1.csv")

# %%
###########################################
# !pip install preprocessor

# %%
import re 
import string
import preprocessor as p
import csv
import tweepy
import pandas as pd

# %%
consumer_key = "ht5wFjij2uE2PAYCJGXvz7GZj"
consumer_secret = "shqczmN4y0qvxa7FPrIZbndEuz8y2deBieWZ6KPl3IRaU7wMcq"
access_key = "1569935221012987904-jfTrFH3RDUDBsQqyr5vO1IDvryryjB"
access_secret = "1U1Yg5MTYsiRNR8dcCkhDyROWwLmGP0NSQkcyVYFz6gZC"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

# %%
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
# search tweets by hasthtags

# %%
csvFile = open('hurt.csv', 'a')
csvWriter = csv.writer(csvFile)

search_words = "#hurt"      #enter tags
new_search = search_words + " -filter:retweets"


for tweet in tweepy.Cursor(api.search,q=new_search,count=100,
                           lang="en",
                           since_id=0).items():
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.user.screen_name.encode('utf-8'), tweet.user.location.encode('utf-8')])
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# c:\users\hp\appdata\local\programs\python\python39\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# --> 953     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
csvFile = open('depressing.csv', 'a')
csvWriter = csv.writer(csvFile)

search_words = "#depressing"      #enter tags
new_search = search_words + " -filter:retweets"


for tweet in tweepy.Cursor(api.search,q=new_search,count=100,
                           lang="en",
                           since_id=0).items():
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.user.screen_name.encode('utf-8'), tweet.user.location.encode('utf-8')])

# %%
depressed =pd.read_csv("tweets.csv")
depressed.shape

# %%
csvFile = open('sad.csv', 'a')
csvWriter = csv.writer(csvFile)

search_words = "#sad"      #enter tags
new_search = search_words + " -filter:retweets"


for tweet in tweepy.Cursor(api.search_tweets,q=new_search,count=100,
                           lang="en",
                           since_id=0).items(1000):
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.user.screen_name.encode('utf-8'), tweet.user.location.encode('utf-8')])

# %%
sad=pd.read_csv("sad.csv")
sad.shape

# %%
csvFile = open('sad1.csv', 'a')
csvWriter = csv.writer(csvFile)

search_words = "#sad"      #enter tags
new_search = search_words + " -filter:retweets"


for tweet in tweepy.Cursor(api.search_tweets,q=new_search,count=100,
                           lang="en",
                           since_id=0).items(10000):
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.user.screen_name.encode('utf-8'), tweet.user.location.encode('utf-8')])

# %%
sad1=pd.read_csv("sad1.csv")
sad1.shape

# %%
################## twint
