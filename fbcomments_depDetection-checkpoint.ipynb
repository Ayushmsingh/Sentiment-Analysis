# %% [markdown]
# # Depression Detection in FB comments

# %% [raw]
# IMPORTING TWEETS

# %%
import nltk  # for text manipulation 
import string # for text manipulation 
import warnings 
import numpy as np 
import pandas as pd # for data manipulation 
import matplotlib.pyplot as plt
import re
from textblob import TextBlob

pd.set_option("display.max_colwidth", 200) 
warnings.filterwarnings("ignore") #ignore warnings

# %% [markdown]
# # Data Preparation

# %%
df = pd.read_csv("./paper_sdata/fbcomments.csv")
df.head()
# Out:
#                                                                                                                                                                                              Comments Text
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...

# %%
df.shape
# Out:
# (4166, 4)

# %%
df.columns=['tweet']
df.head()
# Out:
#                                                                                                                                                                                                      tweet
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...

# %% [markdown]
# # Data Cleaning

# %% [raw]
# REMOVING @ , USERS

# %%
df['Clean_TweetText'] = df['tweet'].str.replace("@", "") 
df.head()
# Out:
#                                                                                                                                                                                                      tweet  \
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...
#
#                                                                                                                                                                                            Clean_TweetText
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...

# %% [raw]
# REMOVING LINKS, HTTP://

# %%
df['Clean_TweetText'] = df['Clean_TweetText'].str.replace(r"http\S+", "") 
df.head()
# Out:
#                                                                                                                                                                                                      tweet  \
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...
#
#                                                                                                                                                                                            Clean_TweetText
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...

# %% [raw]
# REMOVING PUNCTUATIONS, NUMBERS AND SPECIAL CHARACTERS

# %%
df['Clean_TweetText'] = df['Clean_TweetText'].str.replace("[^a-zA-Z]", " ") 
df.head()
# Out:
#                                                                                                                                                                                                      tweet  \
# 0  So, when you ask what the two illnesses are...they're similar in that they tend to have moodiness involved, impulsivity and self-damaging behaviors for compensatory measures. Otherwise, they're no...
# 1  In addition, people with BPD quite often have a weak self concept. They don't always know who they really are deep down inside. They may always feel like there's something missing or something wro...
# 2  Borderline Personality Disorder, like all other personality disorders, is an abnormal way of perceiving and interacting with the world. Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER: Bipolar disease is caused by a chemical imbalance in the brain. It can be treated with medication and therapy. Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts. Ups that last for days ect. Depres...
#
#                                                                                                                                                                                            Clean_TweetText
# 0  So  when you ask what the two illnesses are   they re similar in that they tend to have moodiness involved  impulsivity and self damaging behaviors for compensatory measures  Otherwise  they re no...
# 1  In addition  people with BPD quite often have a weak self concept  They don t always know who they really are deep down inside  They may always feel like there s something missing or something wro...
# 2  Borderline Personality Disorder  like all other personality disorders  is an abnormal way of perceiving and interacting with the world  Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER  Bipolar disease is caused by a chemical imbalance in the brain  It can be treated with medication and therapy  Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts  Ups that last for days ect  Depres...

# %% [raw]
# REMOVE NAN VALUES

# %%
df1=df.dropna()
df1.drop(['tweet'],axis = 1,inplace = True)
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText
# 0  So  when you ask what the two illnesses are   they re similar in that they tend to have moodiness involved  impulsivity and self damaging behaviors for compensatory measures  Otherwise  they re no...
# 1  In addition  people with BPD quite often have a weak self concept  They don t always know who they really are deep down inside  They may always feel like there s something missing or something wro...
# 2  Borderline Personality Disorder  like all other personality disorders  is an abnormal way of perceiving and interacting with the world  Think of it as having a dirty filter that the sufferer sees ...
# 3  LONG ANSWER  Bipolar disease is caused by a chemical imbalance in the brain  It can be treated with medication and therapy  Typically people with bipolar disease have learned to compensate for it ...
# 4  Well think of bipolar as a rollar coaster you have high and low peaks where your mood can either rapidly alternate up and down or have the longwr lasting shifts  Ups that last for days ect  Depres...

# %%
df1.shape
# Out:
# (7145, 1)

# %% [raw]
# REMOVING STOPWORDS

# %%
import nltk
nltk.download('stopwords')
stopwords=nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stopwords(text):
    clean_text=' '.join([word for word in text.split() if word not in stopwords])
    return clean_text

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda text : remove_stopwords(text.lower()))
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText
# 0  ask two illnesses similar tend moodiness involved impulsivity self damaging behaviors compensatory measures otherwise really similar seem like one another often show person making lives chaotic di...
# 1  addition people bpd quite often weak self concept always know really deep inside may always feel like something missing something wrong intrinsically cause periods dissociation difficulty maintain...
# 2  borderline personality disorder like personality disorders abnormal way perceiving interacting world think dirty filter sufferer sees world constantly believe caused chemical imbalances brain poss...
# 3  long answer bipolar disease caused chemical imbalance brain treated medication therapy typically people bipolar disease learned compensate unhealthy ways illegal drug use eating disorders gambling...
# 4  well think bipolar rollar coaster high low peaks mood either rapidly alternate longwr lasting shifts ups last days ect depression anger two common borderline personality like tilt wirl moods go se...

# %% [raw]
# TEXT TOKENIZATION AND NORMALIZATION

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: x.split())
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText
# 0  [ask, two, illnesses, similar, tend, moodiness, involved, impulsivity, self, damaging, behaviors, compensatory, measures, otherwise, really, similar, seem, like, one, another, often, show, person,...
# 1  [addition, people, bpd, quite, often, weak, self, concept, always, know, really, deep, inside, may, always, feel, like, something, missing, something, wrong, intrinsically, cause, periods, dissoci...
# 2  [borderline, personality, disorder, like, personality, disorders, abnormal, way, perceiving, interacting, world, think, dirty, filter, sufferer, sees, world, constantly, believe, caused, chemical,...
# 3  [long, answer, bipolar, disease, caused, chemical, imbalance, brain, treated, medication, therapy, typically, people, bipolar, disease, learned, compensate, unhealthy, ways, illegal, drug, use, ea...
# 4  [well, think, bipolar, rollar, coaster, high, low, peaks, mood, either, rapidly, alternate, longwr, lasting, shifts, ups, last, days, ect, depression, anger, two, common, borderline, personality, ...

# %%
from nltk.stem.porter import * 
stemmer = PorterStemmer() 
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: [stemmer.stem(i) for i in x])
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText
# 0  [ask, two, ill, similar, tend, moodi, involv, impuls, self, damag, behavior, compensatori, measur, otherwis, realli, similar, seem, like, one, anoth, often, show, person, make, live, chaotic, diff...
# 1  [addit, peopl, bpd, quit, often, weak, self, concept, alway, know, realli, deep, insid, may, alway, feel, like, someth, miss, someth, wrong, intrins, caus, period, dissoci, difficulti, maintain, h...
# 2  [borderlin, person, disord, like, person, disord, abnorm, way, perceiv, interact, world, think, dirti, filter, suffer, see, world, constantli, believ, caus, chemic, imbal, brain, possibl, symptom,...
# 3  [long, answer, bipolar, diseas, caus, chemic, imbal, brain, treat, medic, therapi, typic, peopl, bipolar, diseas, learn, compens, unhealthi, way, illeg, drug, use, eat, disord, gambl, promiscu, al...
# 4  [well, think, bipolar, rollar, coaster, high, low, peak, mood, either, rapidli, altern, longwr, last, shift, up, last, day, ect, depress, anger, two, common, borderlin, person, like, tilt, wirl, m...

# %% [raw]
# STITCHING THESE TOKENS TOGETHER

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: ' '.join([w for w in x]))
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText
# 0  ask two ill similar tend moodi involv impuls self damag behavior compensatori measur otherwis realli similar seem like one anoth often show person make live chaotic difficult dysfunct intens frien...
# 1  addit peopl bpd quit often weak self concept alway know realli deep insid may alway feel like someth miss someth wrong intrins caus period dissoci difficulti maintain healthi sens self esteem may ...
# 2  borderlin person disord like person disord abnorm way perceiv interact world think dirti filter suffer see world constantli believ caus chemic imbal brain possibl symptom might medic help suffer h...
# 3  long answer bipolar diseas caus chemic imbal brain treat medic therapi typic peopl bipolar diseas learn compens unhealthi way illeg drug use eat disord gambl promiscu alcohol self harm etc therapi...
# 4  well think bipolar rollar coaster high low peak mood either rapidli altern longwr last shift up last day ect depress anger two common borderlin person like tilt wirl mood go secerap direct rapidli...

# %% [raw]
# REMOVING SMALL WORDS

# %%
df1['Clean_TweetText'] = df1['Clean_TweetText'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText
# 0  similar tend moodi involv impuls self damag behavior compensatori measur otherwis realli similar seem like anoth often show person make live chaotic difficult dysfunct intens friend concern asham ...
# 1  addit peopl quit often weak self concept alway know realli deep insid alway feel like someth miss someth wrong intrins caus period dissoci difficulti maintain healthi sens self esteem weak valu sy...
# 2  borderlin person disord like person disord abnorm perceiv interact world think dirti filter suffer world constantli believ caus chemic imbal brain possibl symptom might medic help suffer help ever...
# 3  long answer bipolar diseas caus chemic imbal brain treat medic therapi typic peopl bipolar diseas learn compens unhealthi illeg drug disord gambl promiscu alcohol self harm therapi assist overcom ...
# 4  well think bipolar rollar coaster high peak mood either rapidli altern longwr last shift last depress anger common borderlin person like tilt wirl mood secerap direct rapidli impulsiv major part w...

# %% [markdown]
# # Data Visualization

# %%
all_words = ' '.join([text for text in df1['Clean_TweetText']])

from wordcloud import WordCloud 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words) 

plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off') 
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity
df1['polarity'] = df1['Clean_TweetText'].apply(polarity)
df1['subjectivity'] = df1['Clean_TweetText'].apply(subjectivity)

# %%
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText  \
# 0  similar tend moodi involv impuls self damag behavior compensatori measur otherwis realli similar seem like anoth often show person make live chaotic difficult dysfunct intens friend concern asham ...
# 1  addit peopl quit often weak self concept alway know realli deep insid alway feel like someth miss someth wrong intrins caus period dissoci difficulti maintain healthi sens self esteem weak valu sy...
# 2  borderlin person disord like person disord abnorm perceiv interact world think dirti filter suffer world constantli believ caus chemic imbal brain possibl symptom might medic help suffer help ever...
# 3  long answer bipolar diseas caus chemic imbal brain treat medic therapi typic peopl bipolar diseas learn compens unhealthi illeg drug disord gambl promiscu alcohol self harm therapi assist overcom ...
# 4  well think bipolar rollar coaster high peak mood either rapidli altern longwr last shift last depress anger common borderlin person like tilt wirl mood secerap direct rapidli impulsiv major part w...
#
#    polarity  subjectivity
# 0 -0.090909      0.575000
# 1 -0.095112      0.559386
# 2 -0.074210      0.457146
# 3  0.002716      0.452262
# 4 -0.038241      0.300741

# %%
#visualizations

# Let’s plot the results
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]
for index, Tweets in enumerate(df1.index):
    x = df1.polarity.loc[Tweets]
    y = df1.subjectivity.loc[Tweets]
    plt.scatter(x, y, color='Red')
 
 
plt.title('Sentiment Analysis', fontsize = 20)
plt.xlabel('← Negative — — — — — — Positive →', fontsize=15)
plt.ylabel('← Facts — — — — — — — Opinions →', fontsize=15)
# Out:
# Text(0, 0.5, '← Facts — — — — — — — Opinions →')

# %%
# Creating function for calculating positive, negative and neutral
# More than 1 --> Positive, equal to 0 --> neutral and less than 0 --> Negative
def ratio(x):
    if x > 0:
        return 1
    elif x == 0:
        return 0
    else:
        return -1
df1['analysis'] = df1['polarity'].apply(ratio)

# %%
df1.head()
# Out:
#                                                                                                                                                                                            Clean_TweetText  \
# 0  similar tend moodi involv impuls self damag behavior compensatori measur otherwis realli similar seem like anoth often show person make live chaotic difficult dysfunct intens friend concern asham ...
# 1  addit peopl quit often weak self concept alway know realli deep insid alway feel like someth miss someth wrong intrins caus period dissoci difficulti maintain healthi sens self esteem weak valu sy...
# 2  borderlin person disord like person disord abnorm perceiv interact world think dirti filter suffer world constantli believ caus chemic imbal brain possibl symptom might medic help suffer help ever...
# 3  long answer bipolar diseas caus chemic imbal brain treat medic therapi typic peopl bipolar diseas learn compens unhealthi illeg drug disord gambl promiscu alcohol self harm therapi assist overcom ...
# 4  well think bipolar rollar coaster high peak mood either rapidli altern longwr last shift last depress anger common borderlin person like tilt wirl mood secerap direct rapidli impulsiv major part w...
#
#    polarity  subjectivity  analysis
# 0 -0.090909      0.575000        -1
# 1 -0.095112      0.559386        -1
# 2 -0.074210      0.457146        -1
# 3  0.002716      0.452262         1
# 4 -0.038241      0.300741        -1

# %%
df1['analysis'].value_counts()
# Out:
#  1    3690
# -1    1926
#  0    1529
# Name: analysis, dtype: int64

# %%
df1['analysis'] = df1['analysis'].replace([-1,0,1],[0,1,2])

# %%
df1['analysis'].value_counts()
# Out:
# 2    3690
# 0    1926
# 1    1529
# Name: analysis, dtype: int64

# %% [markdown]
# *here 0 means depressive tweets, 1 means neutral tweets and 2 means positive tweets*

# %%
# Plotting
df1['analysis'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Word Clouds

# %% [markdown]
# word cloud for positive words

# %%
positive_words =' '.join([text for text in df1['Clean_TweetText'][df1['analysis'] == 2]]) 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(positive_words)

plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off') 
plt.show()

# %% [markdown]
# word cloud for depressive words

# %%
depressive_words =' '.join([text for text in df1['Clean_TweetText'][df1['analysis'] == 0]]) 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(depressive_words)

plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off') 
plt.show()

# %% [markdown]
# # Model Building

# %%
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression 
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vectorizer = CountVectorizer(stop_words='english') 
cv = count_vectorizer.fit_transform(df1['Clean_TweetText'])
cv.shape
# Out:
# (7145, 8730)

# %%
X_train,X_test,y_train,y_test = train_test_split(cv,df1['analysis'] , test_size=.2,stratify=df1['analysis'], random_state=42)

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# # XGBoost Classifier

# %%
xgbc = XGBClassifier(max_depth=6, n_estimators=1000, nthread= 3)
xgbc.fit(X_train,y_train)
prediction_xgb = xgbc.predict(X_test)
print(accuracy_score(prediction_xgb,y_test))
# Out:
# 0.8852344296710987

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier(n_estimators=1000, random_state=42)
rf.fit(X_train,y_train)
prediction_rf = rf.predict(X_test)
print(accuracy_score(prediction_rf,y_test))
# Out:
# 0.7900629811056683

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
prediction_lr = lr.predict(X_test)
print(accuracy_score(prediction_lr,y_test))
# Out:
# 0.8432470258922323

# %% [markdown]
# # Support Vector Machines (SVM)

# %%
svc = svm.SVC()
svc.fit(X_train,y_train)
prediction_svc = svc.predict(X_test)
print(accuracy_score(prediction_svc,y_test))
# Out:
# 0.7739678096571029
